# %%
import os
import numpy as np
#import matplotlib.pyplot as plt
#from ncmcm.data_loaders.matlab_dataset import Database
#from ncmcm.visualisers.neuronal_behavioural import plotting_neuronal_behavioural
from ncmcm.visualisers.latent_space import LatentSpaceVisualiser

os.chdir('../..')
os.getcwd()
# Out:
# '/home/akshey/Desktop/bundlenet_results'

# %%
# %matplotlib inline
worm_num = 0
b_names = ['Dorsal turn', 'Forward', 'No state', 'Reverse-1', 'Reverse-2', 'Sustained reversal', 'Slowing', 'Ventral turn']
b_names = {idx:name for idx, name in enumerate(b_names)}
for algorithm in ['bundlenet', 'lda', 'pca', 'tsne','tsne_optimised',  'autoencoder', 'autoencoder_optimised', 'autoregressor_autoencoder', 'autoregressor_autoencoder_optimised', 'cebra_hybrid', 'cebra_hybrid_optimised']:
    # Plotting
    y0_ = np.loadtxt(f'data/generated/embeddings/y0__{algorithm}_worm_{worm_num}')
    b_ = np.loadtxt(f'data/generated/embeddings/b__{algorithm}_worm_{worm_num}').astype(int)
    print(algorithm)
    # Plotting latent space dynamics
    vis = LatentSpaceVisualiser(y0_, b_, b_names, show_points=True)
    vis.plot_latent_timeseries()
    # vis.plot_phase_space()
    # vis.rotating_plot(filename=f'figures/rotation_{algorithm}_worm_{worm_num}.gif')
# Out:
# bundlenet
# lda
# pca
# tsne
# tsne_optimised
# autoencoder
# autoencoder_optimised
# autoregressor_autoencoder
# autoregressor_autoencoder_optimised
# cebra_hybrid
# cebra_hybrid_optimised

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
for algorithm in ['bundlenet', 'lda', 'pca', 'tsne','tsne_optimised',  'autoencoder', 'autoencoder_optimised', 'autoregressor_autoencoder', 'autoregressor_autoencoder_optimised', 'cebra_hybrid', 'cebra_hybrid_optimised']:
    # Plotting
    y0_ = np.loadtxt(f'data/generated/embeddings/y0__{algorithm}_worm_{worm_num}')
    b_ = np.loadtxt(f'data/generated/embeddings/b__{algorithm}_worm_{worm_num}').astype(int)
    print(algorithm)
    # Plotting latent space dynamics
    vis = LatentSpaceVisualiser(y0_, b_, b_names)
    #vis.plot_latent_timeseries()
    vis.plot_phase_space()
    # vis.rotating_plot(filename=f'figures/rotation_{algorithm}_worm_{worm_num}.gif')
# Out:
# bundlenet
# <div id='e5fc736c-cf58-45dc-9812-c575ab9de7b6'></div>
# lda
# <div id='76e74e49-870b-45f3-804e-4bfb7e9633af'></div>
# pca
# <div id='c99646f7-5d01-47c1-8d8c-cc0ffb946021'></div>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
#for algorithm in ['bundlenet', 'lda', 'pca', 'tsne',  'autoencoder', 'autoregressor_autoencoder', 'cebra_hybrid']:
for algorithm in ['autoencoder_optimised' ]:#, 'tsne','tsne_optimised',  'autoencoder', 'autoencoder_optimised', 'autoregressor_autoencoder', 'autoregressor_autoencoder_optimised', 'cebra_hybrid', 'cebra_hybrid_optimised']:
    # Plotting
    y0_ = np.loadtxt(f'data/generated/embeddings/y0__{algorithm}_worm_{worm_num}')
    b_ = np.loadtxt(f'data/generated/embeddings/b__{algorithm}_worm_{worm_num}').astype(int)
    print(algorithm)
    # Plotting latent space dynamics
    vis = LatentSpaceVisualiser(y0_, b_, b_names, show_points=True)
    #vis.plot_latent_timeseries()
    vis.plot_phase_space()
    # vis.rotating_plot(filename=f'figures/rotation_{algorithm}_worm_{worm_num}.gif')
# Out:
# autoencoder_optimised
# <div id='43197ae9-90cf-46b5-a7e8-789d9d71dc33'></div>
